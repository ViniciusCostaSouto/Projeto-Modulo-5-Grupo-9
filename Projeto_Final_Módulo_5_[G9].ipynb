# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusCostaSouto/Projeto-Modulo-5-Grupo-9/blob/main/Projeto_Final_M%C3%B3dulo_5_%5BG9%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='white' style='font-size: 30px;'>Projeto de encerramento do módulo 5: Análise de Gastos dos Deputados Federais nos anos de 2019, 2020 e 2021 </font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## **1. O Grupo**
#
#  O Grupo 9 é formado pelos integrantes citados abaixo, com seus respectivos endereços de GitHub e LinkedIn.
#
# *  Fernanda Oliveira
#   - [GitHub](https://github.com/FernandaBz)
#   - [LinkedIn](https://www.linkedin.com/in/fernanda-oliveira-b2768716a/)
#
# *  Gabriel Kanarski
#   - [GitHub](https://github.com/GKCSV)
#   - [LinkedIn](https://www.linkedin.com/in/lucasfarim/)
#
# *  Luana Taynara
#   - [GitHub](https://github.com/lu-taynara)
#   - [LinkedIn](https://www.linkedin.com/in/luanat-silva)
#
# *  Vinícius Costa Souto
#   - [GitHub](https://github.com/ViniciusCostaSouto)
#   - [LinkedIn](https://www.linkedin.com/in/vin%C3%ADcius-costa-souto-937966164/)
#
# *  Vitor Hugo Palmieri
#   - [GitHub](https://github.com/vpurple23)
#   - [LinkedIn](https://www.linkedin.com/in/vitor-hugo-p-7529162b/)
#
#
# ---

# %% [markdown]
# ## **2. Descrição do Projeto (Pdf)**
#
# Você e sua equipe foram escalados pela Procuradoria Geral da República para investigarem os gastos dos parlamentares brasileiros nos anos de 2019, 2020 e 2021. Para isso vocês devem utilizar o conjunto de dados sobre a Cota para o Exercício da Atividade Parlamentar, a CEAP. Em resumo, a CEAP pode ser definida como: “cota única mensal destinada a custear os gastos dos deputados exclusivamente vinculados ao exercício da atividade parlamentar.” Essa ajuda de custo para os nossos digníssimos representantes podem cobrir despesas com alimentação, transporte, hospedagem, consultoria técnica, combustíveis e entre outras.
#
# A CEAP é regida por uma série de regras que podem ser consultadas [aqui](https://www2.camara.leg.br/legin/int/atomes/2009/atodamesa-43-21-maio-2009-588364-norma-cd-mesa.html). Há algumas iniciativas, como o [Serenata de Amor](https://serenata.ai/), que visam acompanhar os gastos realizados pelos nossos políticos e podem ser utilizadas para auxiliar na geração de insights.
#
# A fonte dos dados podem ser conferidas [aqui](https://www2.camara.leg.br/transparencia/cota-para-exercicio-da-atividade-parlamentar/dados-abertos-cota-parlamentar), assim como dicionário de
# dados podem ser visualizados [aqui](https://www2.camara.leg.br/transparencia/cota-para-exercicio-da-atividade-parlamentar/explicacoes-sobre-o-formato-dos-arquivos-xml). Contudo, para facilitar o trabalho de vocês, os dados já estão disponibilizados [aqui](https://drive.google.com/drive/u/0/folders/1H_uQc8UTzA1is3jjZjmrFRIabiOUHoIi), nos arquivos: Ano-2019.csv, Ano-2020.csv e Ano-2021.
#
# **As perguntas a serem respondidas são:**
#
# 1. Como se comportam os gastos com cotas parlamentares ao longo
# do tempo? Existe alguma tendência de aumento ou redução desse
# custo?
#
# 2. Qual a média de gastos por parlamentar?
#
# 3. Quais foram os parlamentares que mais e que menos consumiram
# recursos?
#
# 4. Quais são as categorias de despesas mais onerosas dentre os
# recursos destinados às cotas parlamentares?
#
# 5. Quais são os trechos de viagem mais recorrentes entre as despesas
# de viagem?
#
# 6. Qual a média de gastos por estado?
#
# 7. Qual é o valor total de gastos por estado?
#
# 8. Quais estados têm maior número de representantes?
#
# 9. Há alguma correlação entre a quantidade de parlamentares por
# estado e o valor total dos gastos?
#
# 10. Qual a média de gastos por partido?
#
# 11. Quais são os partidos que mais e que menos consumiram a
# cota parlamentar?
#
# 12. Há alguma correlação entre a quantidade de parlamentares
# por partido e o valor total dos gastos?

# %% [markdown]
# ## **3. O Projeto deverá obrigatoriamente:**
#
# * Utilizar Jupyter Notebook ou Colab;
# * Realizar a limpeza dos dados;
# * Realizar análise exploratório;
# * Responder cada uma das perguntas com a visualização mais adequada;
# * O notebook utilizado na análise deve estar organizado, com descrições
# do passo a passo da análise em markdown, apresentação dos resultados e
# insights gerados;
# * Levantar mais duas perguntas e respondê-las com a visualização mais
# adequada.
#
# Apresentação:
# * Todos os integrantes do grupo deverão apresentar
# * Apresente a análise realizada e organizada no Jupyter Notebook ou
# Colab
# * Utilize slides de apoio para sua apresentação
# * Seu grupo terá 15 minutos (no máximo) para apresentar
#
#
#
# ---

# %% [markdown]
# ## **4. Entendendo os Dados:**
#
# Este projeto visa a análise dos dados referentes às despesas públicas pessoais de parlamentares. A Cota para o Exercício da Atividade Parlamentar – CEAP – é uma verba indenizatória à qual os deputados federais e os senadores têm direito para custear as despesas do mandato, com passagens aéreas, alimentação, divulgação da atividade parlamentar, entre outras.
# O valor da cota varia entre os estados devido às diferentes distâncias de Brasília para cada localidade do Brasil. Nesta etapa estaremos coletando os dados iniciais, descrevendo os referidos dados, bem como explorando os dados com as estatísticas descritivas e por fim, verificando a qualidade de dados.

# %% [markdown]
# ### **4.1 Importando as bibliotecas:**

# %% [markdown]
# **Eixo base:**
#  1. NumPy
#
# Biblioteca de manipulação de arrays multidimensionais de alta performance, possui diversas funções matemáticas e estatísticas.
#
#  2. Pandas
#
# Principal biblioteca de manipulação e análise de dados. Possui diversos métodos para agrupar, filtrar, manipular, limpar e combinar dados de forma simples.
#
# **Data Visualization:**
#
#  3. Matplotlib
#
# O matplotlib é uma biblioteca com recursos para a geração de gráficos 2D a partir de arrays.
#
#  4. Seaborn
#
# O Seaborn é uma biblioteca de visualização de dados do Python baseado no Matplotlib. Ele provê uma interface de alto nível para construção de gráficos estatísticos atrativos e informativos.

# %%
# Carregando os pacotes do Python necessários 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import calendar

# %% [markdown]
# ### **4.2 Coletando os dados iniciais:**

# %% [markdown]
# Subindo os dataframes divididos por seus anos respectivos

# %%
data_2019 = pd.read_csv("https://raw.githubusercontent.com/ViniciusCostaSouto/Projeto-Modulo-5-Grupo-9/main/Ano-2019.csv", sep= ';', dtype={'cpf': 'str'})
data_2019.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2019
# 2        LID.GOV-CD  NaN          NaN                    NaN           2019
# 3        LID.GOV-CD  NaN          NaN                    NaN           2019
# 4        LID.GOV-CD  NaN          NaN                    NaN           2019
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              56          13
# 2  NaN       NaN              56          13
# 3  NaN       NaN              56          13
# 4  NaN       NaN              56          13
#
#                                  txtDescricao  ...  numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# ...

# %%
data_2020 = pd.read_csv("https://raw.githubusercontent.com/ViniciusCostaSouto/Projeto-Modulo-5-Grupo-9/main/Ano-2020.csv", sep= ';', dtype={'cpf': 'str'})
data_2020.head()
# Out:
#          txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  \
# 0  LIDERANÇA DO DEMOCRATAS  NaN          NaN                    NaN
# 1  LIDERANÇA DO DEMOCRATAS  NaN          NaN                    NaN
# 2  LIDERANÇA DO DEMOCRATAS  NaN          NaN                    NaN
# 3  LIDERANÇA DO DEMOCRATAS  NaN          NaN                    NaN
# 4  LIDERANÇA DO DEMOCRATAS  NaN          NaN                    NaN
#
#    nuLegislatura sgUF sgPartido  codLegislatura  numSubCota  \
# 0           2019  NaN       NaN              56           4
# 1           2019  NaN       NaN              56           4
# 2           2019  NaN       NaN              56           4
# 3           2019  NaN       NaN              56           4
# 4           2019  NaN       NaN              56           5
#
#                                     txtDescricao  ...  numAno numParcela  \
# 0  CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.  ...    2020          0
# ...

# %%
data_2021 = pd.read_csv("https://raw.githubusercontent.com/ViniciusCostaSouto/Projeto-Modulo-5-Grupo-9/main/Ano-2021.csv", sep= ';', dtype={'cpf': 'str'})
data_2021.head()
# Out:
#         txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  \
# 0  LIDERANÇA DO CIDADANIA  NaN          NaN                    NaN
# 1  LIDERANÇA DO CIDADANIA  NaN          NaN                    NaN
# 2  LIDERANÇA DO CIDADANIA  NaN          NaN                    NaN
# 3  LIDERANÇA DO CIDADANIA  NaN          NaN                    NaN
# 4  LIDERANÇA DO CIDADANIA  NaN          NaN                    NaN
#
#    nuLegislatura sgUF sgPartido  codLegislatura  numSubCota  \
# 0           2019  NaN       NaN              56          13
# 1           2019  NaN       NaN              56          13
# 2           2019  NaN       NaN              56          13
# 3           2019  NaN       NaN              56          13
# 4           2019  NaN       NaN              56          13
#
#                                  txtDescricao  ...  numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2021          0
# ...

# %% [markdown]
# ### **4.3 Unindo os dados:**

# %%
df = pd.concat([data_2019, data_2020, data_2021], ignore_index=True)
df.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2019
# 2        LID.GOV-CD  NaN          NaN                    NaN           2019
# 3        LID.GOV-CD  NaN          NaN                    NaN           2019
# 4        LID.GOV-CD  NaN          NaN                    NaN           2019
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              56          13
# 2  NaN       NaN              56          13
# 3  NaN       NaN              56          13
# 4  NaN       NaN              56          13
#
#                                  txtDescricao  ...  numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# ...

# %% [markdown]
# ### **4.4 Descrevendo os dados:**

# %% [markdown]
# #### 4.4.1 **Dicionário das Variáveis**

# %% [markdown]
# **1.** **`txNomeParlamentar`** (*Nome Parlamentar*): Nome adotado pelo Parlamentar ao tomar posse do seu mandato. Compõe-se de dois elementos: um prenome e o nome; dois nomes; ou dois prenomes, salvo, a juízo do Presidente da Casa legislativa, que poderá alterar essa regra para que não ocorram confusões.
#
# **2.** **`ideCadastro`** (*Identificador Único do Parlamentar*): Número que identifica unicamente um deputado federal na CD.
#
# **3.** **`nuCarteiraParlamentar`** (*Número da  Carteira Parlamentar*): Documento usado para identificar um deputado federal na CD. Pode alterar a cada Legislatura nova.
#
# **4.** **`nuLegislatura`** (*Número da  Legislatura*): Legislatura: Período de quatro anos coincidente com o mandato parlamentar dos Deputados Federais. No contexto da cota CEAP, representa o ano base de início da legislatura e é utilizado para compor a Carteira Parlamentar, pois esta poderá ser alterada à medida que se muda de Legislatura.
#
# **5.** **`sgUF`** (*Sigla da UF*): No contexto da cota CEAP, representa a unidade da federação pela qual o deputado foi eleito e é utilizada para definir o valor da cota a que o deputado tem.
#
# **6.** **`sgPartido`** (*Sigla do Partido*): O seu conteúdo representa a sigla de um partido. Definição de partido: é uma organização formada por pessoas com interesse ou ideologia comuns, que se associam com o fim de assumir o poder para implantar um programa de governo. Tem personalidade jurídica de direito privado e goza de autonomia e liberdade no que diz respeito à criação, organização e funcionamento, observados os princípios e preceitos constitucionais.
#
# **7.** **`codLegislatura`** (*Código da Legislatura*): Legislatura: Período de quatro anos coincidente com o mandato parlamentar dos Deputados Federais. No contexto da cota CEAP, o seu conteúdo representa o código identificador da Legislatura, que um número ordinal sequencial, alterado de um em um, a cada início de uma nova Legislatura (por exemplo, a Legislatura que iniciou em 2011 é a 54ª Legislatura).
#
# **8.** **`numSubCota`** (*Número da Subcota*): No contexto da Cota CEAP, o conteúdo deste dado representa o código do Tipo de Despesa referente à despesa realizada pelo deputado e comprovada por meio da emissão de um documento fiscal, a qual é debitada na cota do deputado.
#
# **9.** **`txtDescricao`** (*Descrição da Subcota*): O seu conteúdo é a descrição do Tipo de Despesa relativo à despesa em questão.
#
# **10.** **`numEspecificacaoSubCota`** (*Número da Especificação da Subcota*): No contexto da Cota CEAP, há despesas cujo Tipo de Despesa necessita ter uma especificação mais detalhada (por exemplo, “Combustível”). O conteúdo deste dado representa o código desta especificação mais detalhada.
#
# **11.** **`txtDescricaoEspecificacao`** (*Descrição da Especificação da Subcota*): Representa a descrição  especificação mais detalhada de um referido Tipo de Despesa.
#
# **12.** **`txtFornecedor`** (*Fornecedor*): O conteúdo deste dado representa o nome do fornecedor do produto ou serviço presente no documento fiscal
#
# **13.** **`txtCNPJCPF`** (*CNPJ/CPF*): O conteúdo deste dado representa o CNPJ ou o CPF do emitente do documento fiscal, quando se tratar do uso da cota em razão do reembolso despesas comprovadas pela emissão de documentos fiscais.
#
# **14.** **`txtNumero`** (*Número do Documento*): O conteúdo deste dado representa o número de face do documento fiscal emitido ou o número do documento que deu causa à despesa debitada na cota do deputado.
#
# **15.** **`indTipoDocumento`** (*Indicativo de Tipo de Documento Fiscal*): Este dado representa o tipo de documento do fiscal – 0 (Zero), para Nota Fiscal; 1 (um), para Recibo; e 2, para Despesa no Exterior.
#
# **16.** **`datEmissao`** (*Data de Emissão*): O conteúdo deste dado é a data de emissão do documento fiscal ou a data do documento que tenha dado causa à despesa.
#
# **17.** **`vlrDocumento`** (*Valor do Documento*): O seu conteúdo é o valor de face do documento fiscal ou o valor do documento que deu causa à despesa. Quando se tratar de bilhete aéreo, esse valor poderá ser negativo, significando que o referido bilhete é um bilhete de compensação, pois compensa um outro bilhete emitido e não utilizado pelo deputado (idem para o dado vlrLiquido abaixo).
#
# **18.** **`vlrGlosa`** (*Valor da Glosa*): O seu conteúdo representa o valor da glosa do documento fiscal que incidirá sobre o Valor do Documento, ou o valor da glosa do documento que deu causa à despesa.
#
# **19.** **`vlrLiquido`** (*Valor Líquido*): O seu conteúdo representa o valor líquido do documento fiscal ou do documento que deu causa à despesa e será calculado pela diferença entre o Valor do Documento e o Valor da Glosa. É este valor que será debitado da cota do deputado. Caso o débito seja do Tipo Telefonia e o valor seja igual a zero, significa que a despesa foi franqueada.
#
# **20.** **`numMes`** (*Mês*): O seu conteúdo representa o Mês da competência financeira do documento fiscal ou do documento que deu causa à despesa. É utilizado, junto com o ano, para determinar em que período o débito gerará efeito financeiro sobre a cota.
#
# **21.** **`numAno`** (*Ano*): O seu conteúdo representa o Ano da competência financeira do documento fiscal ou do documento que deu causa à despesa. É utilizado, junto com o mês, para determinar em que período o débito gerará efeito financeiro sobre a cota.
#
# **22.** **`numParcela`** (*Número da Parcela*): O seu conteúdo representa o número da parcela do documento fiscal. Ocorre quando o documento tem de ser reembolsado de forma parcelada.
#
# **23.** **`txtPassageiro`** (*Passageiro*): O conteúdo deste dado representa o nome do passageiro, quando o documento que deu causa à despesa se tratar de emissão de bilhete aéreo.
#
# **24.** **`txtTrecho`** (*Trecho*): O conteúdo deste dado representa o trecho da viagem, quando o documento que deu causa à despesa se tratar de emissão de bilhete aéreo.
#
# **25.** **`numLote`** (*Número do Lote*): No contexto da Cota CEAP, o Número do Lote representa uma capa de lote que agrupa os documentos que serão entregues à Câmara para serem ressarcidos. Este dado, juntamente com o Número do Ressarcimento, auxilia a localização do documento no Arquivo da Casa.
#
# **26.** **`numRessarcimento`** (*Número do Ressarcimento*): No contexto da Cota CEAP, o Número do Ressarcimento indica o ressarcimento do qual o documento fez parte por ocasião do processamento do seu reembolso. Este dado, juntamente com o Número do Ressarcimento, auxilia a localização do documento no Arquivo da Casa.
#
# **27.** **`vlrRestituicao`** (*Valor da Restituição*): O seu conteúdo representa o valor restituído do documento fiscal que incidirá sobre o Valor do Documento.
#
# **28.** **`nuDeputadoId`** (*Identificador do Solicitante*): Número que identifica um Parlamentar ou Liderança na Transparência da Cota para Exercício da Atividade Parlamentar.
#
# **29.** **`cpf`** (*CPF*): CPF do parlamentar.
#
# **30.** **`ideDocumento`** (*id do Documento*): Não há informação referente ao que se trata essa coluna.
#
# **31.** **`urlDocumento`** (*url do Documento*): Url da nota fiscal do gasto.

# %%
# Conhecendo o formato do dataset.

df.shape
# Out:
# (555500, 31)

# %%
# Conhecendo as varíaveis e seus tipos.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555500 entries, 0 to 555499
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          555500 non-null  object
#  1   cpf                        553661 non-null  object
#  2   ideCadastro                553759 non-null  float64
#  3   nuCarteiraParlamentar      553759 non-null  float64
#  4   nuLegislatura              555500 non-null  int64
#  5   sgUF                       553759 non-null  object
#  6   sgPartido                  553759 non-null  object
#  7   codLegislatura             555500 non-null  int64
#  8   numSubCota                 555500 non-null  int64
#  9   txtDescricao               555500 non-null  object
#  10  numEspecificacaoSubCota    555500 non-null  int64
#  11  txtDescricaoEspecificacao  136177 non-null  object
#  12  txtFornecedor              555467 non-null  object
# ...

# %%
# Visualizar as 5 primeiras linhas do Dataset.

df.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2019
# 2        LID.GOV-CD  NaN          NaN                    NaN           2019
# 3        LID.GOV-CD  NaN          NaN                    NaN           2019
# 4        LID.GOV-CD  NaN          NaN                    NaN           2019
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              56          13
# 2  NaN       NaN              56          13
# 3  NaN       NaN              56          13
# 4  NaN       NaN              56          13
#
#                                  txtDescricao  ...  numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# ...

# %%
# Visualizar as 5 últimas linhas do Dataset.

df.tail()
# Out:
#           txNomeParlamentar          cpf  ideCadastro  nuCarteiraParlamentar  \
# 555495  Henrique do Paraíso  34709948895   217,036.00                 588.00
# 555496  Henrique do Paraíso  34709948895   217,036.00                 588.00
# 555497  Henrique do Paraíso  34709948895   217,036.00                 588.00
# 555498  Henrique do Paraíso  34709948895   217,036.00                 588.00
# 555499        DaLua do Rota  51172593272   217,330.00                 590.00
#
#         nuLegislatura sgUF     sgPartido  codLegislatura  numSubCota  \
# 555495           2019   SP  REPUBLICANOS              56           5
# 555496           2019   SP  REPUBLICANOS              56           5
# 555497           2019   SP  REPUBLICANOS              56           5
# 555498           2019   SP  REPUBLICANOS              56          10
# 555499           2019   AP           PSC              56          10
#
#                                 txtDescricao  ...  numAno numParcela  \
# ...

# %%
print("O data frame total possui " + str(df.shape[0]) + " linhas e " + str(df.shape[1]) + " colunas!")
# Out:
# O data frame total possui 555500 linhas e 31 colunas!

# %% [markdown]
# ---

# %% [markdown]
# ## **5. Preparação e limpeza dos Dados:**

# %% [markdown]
# ### **5.1 Selecionando os dados:**

# %% [markdown]
# Montando dois dataframes com valores liquidos positivos e negativos separados

# %%
dados_positivos = df[df.vlrLiquido >= 0]
dados_negativos = df[df.vlrLiquido < 0]

# %% [markdown]
# ### **5.2 Consulta extra:**

# %% [markdown]
# Verificando as colunas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555500 entries, 0 to 555499
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          555500 non-null  object
#  1   cpf                        553661 non-null  object
#  2   ideCadastro                553759 non-null  float64
#  3   nuCarteiraParlamentar      553759 non-null  float64
#  4   nuLegislatura              555500 non-null  int64
#  5   sgUF                       553759 non-null  object
#  6   sgPartido                  553759 non-null  object
#  7   codLegislatura             555500 non-null  int64
#  8   numSubCota                 555500 non-null  int64
#  9   txtDescricao               555500 non-null  object
#  10  numEspecificacaoSubCota    555500 non-null  int64
#  11  txtDescricaoEspecificacao  136177 non-null  object
#  12  txtFornecedor              555467 non-null  object
# ...

# %% [markdown]
# Quantidade de ocorrência dos partidos ao longo dos dataframes

# %%
df['sgPartido'].value_counts()
# Out:
# PT               71008
# PSL              67028
# PP               44060
# PL               38495
# MDB              38487
# PSD              36623
# PSB              34907
# PSDB             34371
# REPUBLICANOS     29028
# PDT              28706
# DEM              27015
# PTB              12719
# SOLIDARIEDADE    12350
# PODE             10574
# CIDADANIA         9341
# AVANTE            9257
# PROS              8599
# PSOL              8099
# PCdoB             7288
# PSC               6991
# PATRIOTA          5951
# NOVO              5829
# PV                3761
# PR                1118
# REDE               708
# PRB                531
# S.PART.            377
# PPS                225
# PATRI              154
# PHS                139
# PPL                 20
# Name: sgPartido, dtype: int64

# %% [markdown]
# ### **5.3 Convertendo os valores:**

# %% [markdown]
# Alterando a coluna 'dataEmissao' para datetime

# %%
df.datEmissao.fillna(0,inplace=True)
df.datEmissao = pd.to_datetime(df.datEmissao,format = '%Y/%m/%d')

# %% [markdown]
# Cria coluna com o nome do dia da semana

# %%
diaSemana = df.datEmissao
lista = []
for i in diaSemana:
   lista.append(calendar.day_name[i.weekday()])
DiaSemana = pd.Series(lista)
df = pd.concat([df,DiaSemana],axis=1)
df.rename(columns={0:'DiaSemana'},inplace=True)

# %%
# df['cotaUF'] = df.sgUF.astype('str')
# dic_uf={}
# for i,j in df_cotas.iterrows():
#     dic_uf[j.Estado]=j[1]

# def insere_cotas(x,y):
#     for i,j in y.items():
#         if x==i:
#             x=j
#     return x

# df['cotaUF'] = df.cotaUF.apply(lambda x: insere_cotas(x,dic_uf))

# %%
# criamos uma função pra inserir o mes por extenso e assim poder criar a coluna 'Datacompleta' e plotar os graficos com um entendimento melhor
def mes_extenso(x,dic):
    for i,j in dic.items():
        if x == i:
            x=j
    return x

# %%
# Lista com os meses por extenso 
meses = {1:'Janeiro',2:'Fevereiro',3:'Marco',4:'Abril',5:'Maio',6:'Junho',7:'Julho',8:'Agosto',9:'Setembro',10:'Outubro',11:'Novembro',12:'Dezembro'}

# Aqui usamos a função que criamos para colocar os meses por extenso e criamos uma coluna 'Datacompleta' para colocar o mes e o ano em uma unica coluna
df.sort_values(['numAno','numMes'],inplace=True)
df['Mes']=df.numMes.apply(lambda x :mes_extenso(x,meses))
df['Datacompleta'] = df['numMes']
for i in df.iterrows():
    if i[0]<=len(df)-1:
        df['Datacompleta'][i[0]]=f'{df.Mes[i[0]]} de {df.numAno[i[0]]}'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ### **5.4 Estatísticas Descritivas:**

# %%
pd.options.display.float_format = '{:,.2f}'.format
#Caso as variáveis fiquem em notação científica, é só rodar essa janela

# %%
df.describe().T
# Out:
#                              count         mean          std       min  \
# ideCadastro             553,759.00   166,015.34    45,864.51  4,930.00
# nuCarteiraParlamentar   553,759.00       289.01       153.13      1.00
# nuLegislatura           555,500.00     2,018.89         0.64  2,015.00
# codLegislatura          555,500.00        55.97         0.16     55.00
# numSubCota              555,500.00       250.66       412.07      1.00
# numEspecificacaoSubCota 555,500.00         0.25         0.46      0.00
# indTipoDocumento        555,500.00         1.03         1.57      0.00
# vlrDocumento            555,500.00       884.41     2,464.53 -6,605.57
# vlrGlosa                555,500.00         3.90       139.45      0.00
# vlrLiquido              555,500.00       808.74     2,464.25 -7,821.20
# numMes                  555,500.00         6.08         3.34      1.00
# numAno                  555,500.00     2,019.67         0.78  2,019.00
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **6. Análise Exploratória:**

# %% [markdown]
# Temos abaixo a resolução das questões solicitadas pelo projeto e as que foram sugeridas pela equipe:

# %% [markdown]
# ##**Questões propostas pelo projeto:**

# %% [markdown]
# ### <font size=15>**6.1. Como se comportam os gastos com cotas parlamentares ao longo do tempo? Existe alguma tendência de aumento ou redução desse custo?**

# %% [markdown]
# Para começar a análise, fizemos um grafico por mês, para mostra a evolução dos gastos a cada período.

# %%
#Agrupando por dada Completa
dadospordata= df.groupby(['numAno','numMes','Datacompleta'])[['vlrLiquido']].sum() #adicionei mes e ano no groupby só para ordenar de forma correta
dadospordata.reset_index(inplace=True)
dadospordata.drop(['numAno','numMes'],axis=1,inplace=True)                        # aqui eu deleto as colunas mes e ano pq nao vou usar mais
dadospordata.set_index('Datacompleta',inplace=True)                               # seto o Datacompleta como indice

# %%
fig = plt.figure(figsize=(25,10))
ax = fig.add_subplot(1,1,1)
ax.plot(np.array(dadospordata),marker='.',mew=5,mec='r')
ax.set_xticks(range(len(np.array(dadospordata.index))))               #seta a quantaidade de ticks do eixo x de acordo com o tamanho dos dados
ax.set_xticklabels(np.array(dadospordata.index),rotation=90,size=20)  #seta os ticks do eixo x, colocando por extenso e inclinando
ax.set_yticks(np.array(range(0,30000000,5000000)))                    #seta a quantaidade de ticks do eixo y de acordo com o tamanho dos dados
ax.set_yticklabels(['0','5 M','10 M','15 M','20 M','25 M'],size=20)   #seta os ticks do eixo y, coloando em Milhoes

# plotando os gastos de cada mês no grafico
for i in range(len(dadospordata)):
    x = i
    y = dadospordata.iloc[i]
    plt.text(x,y,s= str((dadospordata.iloc[i]['vlrLiquido']/1000000).round(2))+'M',size=15,position=(x,y+500000),fontsize=13)

# configurações visuais do grafico
font1 = {'family':'serif','size':15,'color':'black'}
font2 = {'family':'serif','size':15,'color':'black'}
plt.title("Gastos totais por periodo", fontdict = font1)
plt.xlabel("Mes-Ano", fontdict = font2)
plt.ylabel("Gastos em Milhoes de Reais", fontdict = font2)
plt.grid()

# %% [markdown]
# <font size=6><b>Podemos observar os gastos realizados por mês. Há uma tendência de queda nos meses finais de 2019, que se manteve em 2020. No entanto, mês que apresenta o pico de gastos de todo o dataset é dezembro de 2020.

# %% [markdown]
# <font size=5>Para explicitar mais ainda foi feito um gráfico com o acumulado de despesas de cada ano, e com isso podemos ver de forma mais concisa a redução dos gastos no período entre 2019 e 2020.

# %%
questao1 = df.groupby('numAno')[['vlrLiquido']].sum()
questao1.reset_index(inplace=True)
questao1.style.format({'vlrLiquido':'R$ {:.2F}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2fa5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >numAno</th>
#       <th class="col_heading level0 col1" >vlrLiquido</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2fa5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2fa5_row0_col0" class="data row0 col0" >2019</td>
#       <td id="T_e2fa5_row0_col1" class="data row0 col1" >R$ 205862505.20</td>
#     </tr>
#     <tr>
#       <th id="T_e2fa5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2fa5_row1_col0" class="data row1 col0" >2020</td>
#       <td id="T_e2fa5_row1_col1" class="data row1 col1" >R$ 152617344.01</td>
#     </tr>
#     <tr>
#       <th id="T_e2fa5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e2fa5_row2_col0" class="data row2 col0" >2021</td>
# ...

# %%
plt.figure(figsize=(9,6))
ax = sns.barplot(data=questao1, x = 'numAno',y='vlrLiquido',color='royalblue')
plt.xlabel('Ano')
plt.ylabel('Milhões de Reais')
plt.title('Gastos totais por ano',size=12)
i=0
for k,valor in questao1.iterrows():
    plt.annotate(f'{round(valor.vlrLiquido/1000000,2)}M',xy=(i,valor.vlrLiquido),xytext=(i-0.1,valor.vlrLiquido+2000000),fontsize=12)
    i=i+1

plt.annotate('*Dados até julho',xy=(2.2,93000000),fontsize=10)
# Out:
# Text(2.2, 93000000, '*Dados até julho')

# %% [markdown]
# <font size=6> Apesar do ano de 2021 estar incompleto, podemos verificar uma tendendia de queda dos gastos

# %% [markdown]
# ### <font size=15> **6.2. Qual a média de gastos por parlamentar?**

# %%
media_gastos_aux1 = df[['txNomeParlamentar', 'vlrLiquido', 'sgPartido', 'sgUF']]
media_gastos_aux2 = media_gastos_aux1.groupby(['txNomeParlamentar', 'sgPartido', 'sgUF']).mean().sort_values(by = 'vlrLiquido', ascending = False).head(10)
media_gastos_parlamentar = media_gastos_aux2.rename(columns = {'vlrLiquido': 'Gasto médio'}).round(3).style.format({'Gasto médio':'R$ {:.2F}'}).background_gradient(cmap='Oranges')
media_gastos_parlamentar
# Out:
# <style type="text/css">
# #T_23306_row0_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_23306_row1_col0 {
#   background-color: #fd8f3e;
#   color: #f1f1f1;
# }
# #T_23306_row2_col0 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_23306_row3_col0 {
#   background-color: #fdc794;
#   color: #000000;
# }
# #T_23306_row4_col0 {
#   background-color: #fdc895;
#   color: #000000;
# }
# #T_23306_row5_col0 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_23306_row6_col0 {
#   background-color: #fdd1a4;
#   color: #000000;
# }
# #T_23306_row7_col0 {
#   background-color: #fdd7af;
#   color: #000000;
# }
# #T_23306_row8_col0 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_23306_row9_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_23306_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
# ...

# %% [markdown]
# <font size = 6>A maior média de gastos é de José Reginaldo do Maranhão.

# %% [markdown]
#  Por curiosidade, fizemos uma tabela interativa, onde podemos ver a soma dos valores, a média e a contagem de ocorrencias e ordenar por uma dessas colunas

# %%
gastos_parlamentar_agg = df.groupby('txNomeParlamentar')[['vlrLiquido']].agg(['sum','mean','count'])
gastos_parlamentar_agg=gastos_parlamentar_agg.droplevel(0,axis=1)
ordenacao = 'count'
gastos_parlamentar_agg.sort_values(ordenacao,ascending=True).head(10)
# Out:
#                         sum      mean  count
# txNomeParlamentar
# LUCIANA SANTOS         0.49      0.49      1
# DaLua do Rota          1.08      1.08      1
# SARNEY FILHO           1.25      1.25      1
# MANDETTA               0.60      0.60      1
# Geraldo Resende        1.66      0.83      2
# JOSÉ REINALDO     40,357.84 13,452.61      3
# RENZO BRAZ           102.71     34.24      3
# MIRO TEIXEIRA        509.67    169.89      3
# ROCHA                  2.53      0.84      3
# ALBERTO FRAGA     30,643.56 10,214.52      3

# %% [markdown]
# <font size = 5> Com essa tabela, verificamos que o parlamentar José Reinaldo possiu uma quantidade baixa de ocorencias, apesar de estar em primeiro lugar na media, por outro lado, a parlamentar Jessica sales tem uma grande quantidade de ocorrencias e uma soma total elevada. Ai decidomos plotar os graficos de gastos no tempo desses dois parlamentares para comparar

# %% [markdown]
# <font size=8>Jéssica Sales

# %% [markdown]
# <font size = 8>

# %%
# Para facilitar a usabilidade, colocamos o nome do parlamentar em uma variavel, assim é so mudar o nome que o grafico já plota os dados referentes ao parlamentar
parlamentar = 'Jéssica Sales'

#filtrando os dados pelo nome do parlamentar
dadosparlamentar= df[df.txNomeParlamentar==parlamentar].groupby(['numAno','numMes','Datacompleta'])[['vlrLiquido']].sum()
dadosparlamentar.reset_index(inplace=True)
dadosparlamentar.drop(['numAno','numMes',],axis=1,inplace=True)
dadosparlamentar.set_index('Datacompleta',inplace=True)

#plota o grafico
fig = plt.figure(figsize=(28,14))
ax = fig.add_subplot(1,1,1)
ax.plot(np.array(dadosparlamentar),marker='.',mew=2,mec='r')
ax.set_xticks(range(len(np.array(dadosparlamentar.index))))
ax.set_xticklabels(np.array(dadosparlamentar.index),rotation=90,size=12)
ax.set_yticks(np.array(range(0,round(dadosparlamentar['vlrLiquido'].max())+30000,25000)))

#plota os valores gastos no mês no grafico
for i in range(len(dadosparlamentar)):
    x = i
    y = dadosparlamentar.iloc[i]
    plt.text(x,y,s= str((dadosparlamentar.iloc[i]['vlrLiquido']/1000).round(2))+'mil',size=13,position=(x,y+1000))

# plota a média geral 
plt.axhline(dadosparlamentar['vlrLiquido'].mean(),linestyle='--',color='r',label=f'Média= {round(dadosparlamentar["vlrLiquido"].mean()/1000,2)} Mil')

#Configuraçoes visuais do gráfico
font1 = {'family':'serif','size':15}
font2 = {'family':'serif','size':15}
plt.title(f"Gastos por periodo - {parlamentar}", fontdict = font1)
plt.xlabel("Mes-Ano", fontdict = font2)
plt.ylabel("Gastos Totais", fontdict = font2)
plt.legend(loc='upper center',fontsize=15)
plt.grid()

# %% [markdown]
# <font size = 8>Plotando grafico do José Reinaldo

# %%
# Para facilitar a usabilidade, colocamos o nome do parlamentar em uma variavel, assim é so mudar o nome que o grafico já plota os dados referentes ao parlamentar
parlamentar = 'JOSÉ REINALDO'

#filtrando os dados pelo nome do parlamentar
dadosparlamentar= df[df.txNomeParlamentar==parlamentar].groupby(['numAno','numMes','Datacompleta'])[['vlrLiquido']].sum()
dadosparlamentar.reset_index(inplace=True)
dadosparlamentar.drop(['numAno','numMes',],axis=1,inplace=True)
dadosparlamentar.set_index('Datacompleta',inplace=True)

#plota o grafico
fig = plt.figure(figsize=(28,14))
ax = fig.add_subplot(1,1,1)
ax.plot(np.array(dadosparlamentar),marker='.',mew=2,mec='r')
ax.set_xticks(range(len(np.array(dadosparlamentar.index))))
ax.set_xticklabels(np.array(dadosparlamentar.index),rotation=90,size=12)
ax.set_yticks(np.array(range(0,round(dadosparlamentar['vlrLiquido'].max())+30000,25000)))

#plota os valores gastos no mês no grafico
for i in range(len(dadosparlamentar)):
    x = i
    y = dadosparlamentar.iloc[i]
    plt.text(x,y,s= str((dadosparlamentar.iloc[i]['vlrLiquido']/1000).round(2))+'mil',size=13,position=(x,y+1000))

# plota a média geral 
plt.axhline(dadosparlamentar['vlrLiquido'].mean(),linestyle='--',color='r',label=f'Média= {round(dadosparlamentar["vlrLiquido"].mean()/1000,2)} Mil')

#Configuraçoes visuais do gráfico
font1 = {'family':'serif','size':15}
font2 = {'family':'serif','size':15}
plt.title(f"Gastos por periodo - {parlamentar}", fontdict = font1)
plt.xlabel("Mes-Ano", fontdict = font2)
plt.ylabel("Gastos Totais", fontdict = font2)
plt.legend(loc='upper center',fontsize=15)
plt.grid()

# %% [markdown]
# <font size=5><b>Como podemos ver nos gráficos acima, o parlamentar José Reinaldo tem a maior média de gasto por ocorencia simples, mas seu gasto ocorreu em apenas um único mês em toda análise.
# Jéssica Sales, no entanto, teve uma média alta e uma grande quantidade de ocorrências, ou seja, manteve gastos constante ao longo do período analisado.
# Isso nos leva  a uma conclusão que uma média simples nem sempre nos diz muita coisa sobre os dados.

# %% [markdown]
# ### <font size=15> **6.3. Quais foram os parlamentares que mais e que menos consumiram recursos?**

# %%
questao3_1 = df.groupby('txNomeParlamentar')[['vlrLiquido']].sum().sort_values('vlrLiquido', ascending=False).head(10).style.format({'vlrLiquido':'R$ {:.2F}'}).background_gradient(cmap='Oranges')
questao3_1
# Out:
# <style type="text/css">
# #T_baa04_row0_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_baa04_row1_col0 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_baa04_row2_col0 {
#   background-color: #f57622;
#   color: #f1f1f1;
# }
# #T_baa04_row3_col0 {
#   background-color: #fdaf6c;
#   color: #000000;
# }
# #T_baa04_row4_col0 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_baa04_row5_col0 {
#   background-color: #fee7d1;
#   color: #000000;
# }
# #T_baa04_row6_col0 {
#   background-color: #fee9d3;
#   color: #000000;
# }
# #T_baa04_row7_col0 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_baa04_row8_col0 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_baa04_row9_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_baa04_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >vlrLiquido</th>
# ...

# %% [markdown]
# <font size = 6>Os 3 parlamentares que mais consumiram recurso foram Jéssica sales, Wellington Roberto e Silas Câmara

# %%
# Menores
questao3_2 = dados_positivos.groupby('txNomeParlamentar')[['vlrLiquido']].sum().sort_values('vlrLiquido')
questao3_2.head(5).style.format({'vlrLiquido':'R$ {:.2F}'}).background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ca168_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ca168_row1_col0 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_ca168_row2_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_ca168_row3_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_ca168_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ca168_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >vlrLiquido</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >txNomeParlamentar</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca168_level0_row0" class="row_heading level0 row0" >LUCIANA SANTOS</th>
#       <td id="T_ca168_row0_col0" class="data row0 col0" >R$ 0.49</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <font size = 6>Luciana Santos lidera a lista dos que menos gastaram a cota parlamenta

# %% [markdown]
# <font size=5><b>Como um pequeno extra decidimos verificar os gastos dos dois parlamentares que mais gastaram, Jessica Sales e Wellington Roberto

# %% [markdown]
# <font size=6>JESSICA SALES

# %%
parlamentar = 'Jéssica Sales'
categoria_parlamentar = df[df.txNomeParlamentar==parlamentar].groupby(['txtDescricao'])[['vlrLiquido']].sum().sort_values('vlrLiquido',ascending=False)
plt.figure(figsize=(8,6))
sns.barplot(data=categoria_parlamentar,x='vlrLiquido',y=categoria_parlamentar.index,palette='rocket')
plt.ylabel('Categoria')
plt.xlabel('Valor em Milhões de reais')
categoria_parlamentar.style.format({'vlrLiquido':'R$ {:.2F}'}).background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_d7b62_row0_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_d7b62_row1_col0 {
#   background-color: #fdba7f;
#   color: #000000;
# }
# #T_d7b62_row2_col0 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_d7b62_row3_col0 {
#   background-color: #feead6;
#   color: #000000;
# }
# #T_d7b62_row4_col0 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_d7b62_row5_col0 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_d7b62_row6_col0 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_d7b62_row7_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_d7b62_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >vlrLiquido</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >txtDescricao</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %% [markdown]
# <font size=6>WELLINGTON ROBERTO

# %%
parlamentar = 'Wellington Roberto'
categoria_parlamentar2 = df[df.txNomeParlamentar==parlamentar].groupby(['txtDescricao'])[['vlrLiquido']].sum().sort_values('vlrLiquido',ascending=False)
plt.figure(figsize=(8,6))
sns.barplot(data=categoria_parlamentar2,x='vlrLiquido',y=categoria_parlamentar2.index,palette='rocket')
plt.ylabel('Categoria')
plt.xlabel('Valor em Milhões de reais')
categoria_parlamentar2.style.format({'vlrLiquido':'R$ {:.2F}'}).background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_c8ecf_row0_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_c8ecf_row1_col0 {
#   background-color: #fdd9b4;
#   color: #000000;
# }
# #T_c8ecf_row2_col0 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_c8ecf_row3_col0, #T_c8ecf_row4_col0 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_c8ecf_row5_col0, #T_c8ecf_row6_col0 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_c8ecf_row7_col0, #T_c8ecf_row8_col0, #T_c8ecf_row9_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_c8ecf_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >vlrLiquido</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >txtDescricao</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# <font size = 5>Aqui fizemos uma análise da quantidade de eventos com a soma total dos gastos

# %% [markdown]
# <font size = 5>O gráfico de dispersão mostra a quantidade de gastos e a soma total.
# Com isso podemos ver como os parlamentares gastaram em relação a quantidade de ocorrencias

# %%
plt.figure(figsize=(15,6))
ax= sns.scatterplot(data=gastos_parlamentar_agg,y='sum',x='count')
plt.xlabel('Ocorrencias')
plt.ylabel('Soma em milhoes de reais')
plt.title('Gasto total do parlamentar x contagem de ocorrencias')
plt.yticks(range(0,1500000,200000))
ax.set_yticklabels(['0','0.2 M','0.4 M','0.6 M','0.8 M','1 M','1.2 M','1.4 M'],size=10)
plt.show()

# %% [markdown]
# ###<font size=15> **6.4. Quais são as categorias de despesas mais onerosas dentre os recursos destinados às cotas parlamentares?**

# %% [markdown]
# <font size = 6>Analisando os dados acumulados

# %%
questao4 = df.groupby(['txtDescricao'])[['vlrLiquido']].sum().sort_values('vlrLiquido',ascending=False)
questao4.reset_index(inplace=True)

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=questao4,x='txtDescricao',y='vlrLiquido')
plt.xticks(rotation=90)
plt.xlabel('')
plt.ylabel('Valor total em reais')
i=0
for k,valor in questao4.iterrows():
    plt.annotate(f'R$ {round(valor[1]/1000000,2)}M',xy=(i,valor[1]),xytext=(i-0.4,valor[1]+1000000))
    i=i+1

# %% [markdown]
# <font size = 6>Análise por ano

# %%
questao4_2 = df.groupby(['numAno','txtDescricao'])[['vlrLiquido']].sum().sort_values('vlrLiquido',ascending=False)
questao4_2.reset_index(inplace=True)

# %%
plt.figure(figsize=(20,10))
ax=sns.barplot(data=questao4_2,x='txtDescricao',y='vlrLiquido',hue='numAno',orient='v')
plt.xticks(rotation=90)
plt.legend(title='Ano',loc='upper center')
plt.ylabel('Valores em milhões de reais')
plt.xlabel('')
for i in ax.patches:
    ax.annotate(f'{(i.get_height()/1000000).round(2)}M',
                  (i.get_x() + i.get_width() / 2, i.get_height()),
                  ha='center',
                  fontsize=10,
                  color='black',
                  xytext=(11, 2),
                  textcoords='offset points')
plt.annotate('2021:Dados até julho',xy=(9.7,50000000))
# Out:
# Text(9.7, 50000000, '2021:Dados até julho')

# %% [markdown]
# <font size = 6>Frequência de categorias

# %%
plt.figure(figsize=(10,8))
sns.histplot(df.txtDescricao)
plt.xticks(rotation=90)
plt.title('Quantidade de ocorrencias por categorias')
plt.ylabel('Quantidade')
plt.show()

# %% [markdown]
# <font size = 6>É possível verificar que a maior quantidade de gastos é realizada com a divulgação da atividade parlamentar. Além disso, fica evidente a queda dos gastos com passagens aéreas nos anos de 2020 e 2021 quando as duas casas legislativas passaram a trabalhar remotamente devido à pandemia de covid-19.

# %% [markdown]
# ### <font size=15>**6.5. Quais são os trechos de viagem mais recorrentes entre as despesas de viagem?**

# %%
questao5 = df.groupby('txtTrecho')[['txNomeParlamentar']].count().sort_values('txNomeParlamentar',ascending=False).head(10)
questao5
# Out:
#            txNomeParlamentar
# txtTrecho
# BSB/BSB                 9890
# BSB/CGH                 5083
# CGH/BSB                 4912
# BSB/SDU                 4134
# SDU/BSB                 3987
# BSB/CNF                 3929
# BSB/SSA                 3737
# CNF/BSB                 3674
# SSA/BSB                 3415
# BSB/REC                 2894

# %%
teste = df.groupby('txtTrecho')[['vlrLiquido']].sum().sort_values('vlrLiquido',ascending=False)
teste.head(10)
# Out:
#             vlrLiquido
# txtTrecho
# BSB/CGH   3,557,278.27
# CGH/BSB   3,334,863.21
# BSB/SSA   2,586,750.65
# BSB/SDU   2,219,903.06
# SSA/BSB   2,085,209.92
# SDU/BSB   1,949,747.57
# BSB/CNF   1,617,222.08
# BSB/REC   1,597,164.86
# BSB/POA   1,595,847.38
# BSB/FOR   1,531,098.15

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=questao5,x=questao5.index,y='txNomeParlamentar', palette = "Greens_r")
plt.xticks(rotation=90)
plt.title('Quantidade Trechos')
plt.ylabel('Quantidade')
plt.xlabel('')
plt.show()

# %% [markdown]
# ### <font size=15>**6.6. Qual a média de gastos por estado?**

# %%
questao6 = df.groupby('sgUF').mean()[['vlrLiquido']].sort_values('vlrLiquido',ascending=False)
questao6
# Out:
#       vlrLiquido
# sgUF
# AP      1,712.18
# AC      1,535.89
# DF      1,524.55
# AM      1,520.01
# RR      1,453.14
# PI      1,387.42
# SE      1,301.52
# GO      1,274.14
# MA      1,257.76
# AL      1,152.57
# PA      1,143.53
# CE      1,117.25
# PB        955.55
# BA        910.25
# MS        871.06
# TO        844.20
# ES        838.89
# RO        788.92
# MT        775.90
# PE        763.17
# RN        736.55
# RJ        724.39
# MG        662.08
# PR        640.56
# SP        627.56
# RS        517.38
# SC        488.58

# %% [markdown]
# Verificando qual categoria mais gasta por estado

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=questao6,x=questao6.index,y='vlrLiquido', palette = "Reds_r")
plt.xticks(rotation=90)
plt.title('Media de gastos por estado')
plt.ylabel('Media em reais')
plt.xlabel('')
plt.show()

# %% [markdown]
# ### <font size=15> **6.7. Qual é o valor total de gastos por estado?**

# %%
total_estados = df.groupby('sgUF').sum()[['vlrLiquido']].sort_values('vlrLiquido',ascending=False)
total_estados
# Out:
#         vlrLiquido
# sgUF
# SP   52,635,438.40
# MG   43,162,671.56
# BA   39,441,897.60
# RJ   36,707,801.80
# PR   26,785,753.60
# RS   25,075,845.74
# CE   21,933,892.08
# PE   21,591,701.23
# MA   18,126,874.79
# PA   16,469,118.51
# GO   14,416,890.65
# PB   12,161,287.75
# AC   10,293,532.20
# PI   10,105,986.48
# SC    9,722,726.40
# AP    8,930,724.82
# AM    8,698,992.79
# ES    7,982,895.03
# SE    7,970,503.96
# TO    7,916,891.67
# RR    7,854,212.79
# AL    7,640,373.82
# RN    7,500,253.34
# MT    7,184,822.30
# MS    6,942,314.37
# RO    5,926,355.59
# DF    4,303,815.07

# %%
total_estados_ano = df.groupby(['numAno','sgUF']).sum()[['vlrLiquido']].sort_values('vlrLiquido',ascending=False)
total_estados_ano.reset_index(inplace=True)
total_estados_ano[total_estados_ano.sgUF=='SP']
# Out:
#     numAno sgUF    vlrLiquido
# 0     2019   SP 24,719,979.40
# 4     2020   SP 17,019,305.04
# 10    2021   SP 10,896,153.96

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=total_estados_ano,x='sgUF',y='vlrLiquido',hue='numAno')

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=total_estados,x=total_estados.index,y='vlrLiquido', palette ="viridis")
plt.xticks(rotation=90)
plt.title('Soma de gastos por estado')
plt.ylabel('Milhões de reais')
plt.xlabel('')
plt.show()

# %% [markdown]
# ### <font size=15>**6.8. Quais estados têm maior número de representantes?**

# %% [markdown]
# Dividindo por ano

# %%
parlamentares2019 = data_2019[['sgUF','txNomeParlamentar']].drop_duplicates().groupby('sgUF').count().sort_values('txNomeParlamentar',ascending=False)
parlamentares2020 = data_2020[['sgUF','txNomeParlamentar']].drop_duplicates().groupby('sgUF').count().sort_values('txNomeParlamentar',ascending=False)
parlamentares2021 = data_2021[['sgUF','txNomeParlamentar']].drop_duplicates().groupby('sgUF').count().sort_values('txNomeParlamentar',ascending=False)
parlamentaresTotal = df[['sgUF','txNomeParlamentar']].drop_duplicates().groupby('sgUF').count().sort_values('txNomeParlamentar',ascending=False)
paralmentarPorAno = pd.concat([parlamentares2019,parlamentares2020,parlamentares2021,parlamentaresTotal],axis=1)
paralmentarPorAno.columns = ['2019','2020','2021','Total']
paralmentarPorAno
# Out:
#       2019  2020  2021  Total
# sgUF
# SP     102    74    71    104
# MG      81    55    53     81
# RJ      80    47    52     82
# BA      55    40    41     56
# RS      46    33    34     47
# PR      45    31    31     46
# PE      37    25    25     38
# CE      35    27    28     39
# MA      32    21    21     34
# GO      27    17    17     27
# SC      27    18    18     30
# PA      26    17    18     27
# PB      18    12    14     20
# MS      16     8    10     16
# ES      16    10    11     17
# MT      15     8     9     15
# PI      15    12    10     15
# AC      14     9     9     14
# AL      14     9    10     14
# DF      14     8     8     15
# AP      14     9    10     15
# AM      14     8     8     14
# RO      13     8     8     13
# RN      12     9     9     13
# RR      12     9     9     13
# SE      12     8     8     12
# TO      12     8     8     12

# %% [markdown]
# O Congresso Nacional é formado por duas casas, a Câmara dos Deputados que representa a população dos Estados e o Senado Federal que representa cada Estado da Federação. No total são 513 deputados federais divididos proporcionalmente pelo quantitativo da população de cada um dos 26 estados e Distrito Federal. Por exemplo SP é o mais populoso e tem 70 deputados, número máximo permitido e outros 11 estados menos populosos, possuem 8 representantes, número mínimo permitido.
#
# No senado todos os Estados e DF possuem o mesmo número de representantes, cada um possui 3 senadores. No total então são 513 deputados e 81 senadores no exercício da função.

# %%
total_parlamentar_por_estado = df[['sgUF','txNomeParlamentar']].drop_duplicates().groupby('sgUF').count().sort_values('txNomeParlamentar',ascending=False)
total_parlamentar_por_estado
# Out:
#       txNomeParlamentar
# sgUF
# SP                  104
# RJ                   82
# MG                   81
# BA                   56
# RS                   47
# PR                   46
# CE                   39
# PE                   38
# MA                   34
# SC                   30
# GO                   27
# PA                   27
# PB                   20
# ES                   17
# MS                   16
# MT                   15
# DF                   15
# PI                   15
# AP                   15
# AC                   14
# AL                   14
# AM                   14
# RO                   13
# RR                   13
# RN                   13
# SE                   12
# TO                   12

# %% [markdown]
# Nos dados encontrados são considerados todos os parlamentares que estiveram em exercício da função durante os anos de 2019 e 2021 (até julho), o que inclui suplentes.
# Percebe-se que como o estado com mais representantes acumulados no período se mantém São Paulo e pouco muda nos dados analisados com relação à quantidade já pré estabelecida em lei.

# %% [markdown]
# ### <font size=15>**6.8.1 Dados Sobre as lideranças**
# Analisando o dataset, nós verificamos que existem dados que são referentes às lideranças da câmara e do senado e que estão separados como: lideranças de partido, do governo e da minoria.

# %%
liderancas = df[df.txNomeParlamentar.str.contains("LID", regex=False)]
liderancas
# Out:
#            txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  \
# 0                 LID.GOV-CD  NaN          NaN                    NaN
# 171         LIDERANÇA DO PDT  NaN          NaN                    NaN
# 191     LIDERANÇA DO PODEMOS  NaN          NaN                    NaN
# 192     LIDERANÇA DO PODEMOS  NaN          NaN                    NaN
# 267         LIDERANÇA DO PSD  NaN          NaN                    NaN
# ...                      ...  ...          ...                    ...
# 450243       LIDERANÇA DO PT  NaN          NaN                    NaN
# 450293      LIDERANÇA DO PTB  NaN          NaN                    NaN
# 450294      LIDERANÇA DO PTB  NaN          NaN                    NaN
# 450295      LIDERANÇA DO PTB  NaN          NaN                    NaN
# 450316      LIDERANÇA DO PTB  NaN          NaN                    NaN
#
#         nuLegislatura sgUF sgPartido  codLegislatura  numSubCota  \
# ...

# %% [markdown]
# Então, nós filtramos os valores de gastos, ranqueamos e somamos para obter o total de gastos nesses 31 meses.

# %%
liderancas_aux1 = liderancas[['txNomeParlamentar', 'vlrLiquido' ]]
liderancas_aux2 = liderancas_aux1.groupby(['txNomeParlamentar']).sum().sort_values('vlrLiquido', ascending=False).round(3)
gastos_liderancas = liderancas_aux2.rename(columns = {'vlrLiquido': 'Gasto total'}).round(2)
gastos_liderancas
# Out:
#                                                   Gasto total
# txNomeParlamentar
# LIDERANÇA DO PT                                    445,926.54
# LIDERANÇA DO PDT                                   271,181.80
# LIDERANÇA DO PSDB                                  140,218.69
# LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL   125,704.52
# LIDERANÇA DO PSD                                   122,840.61
# LIDERANÇA DO PODEMOS                               110,837.08
# LIDERANÇA DO SOLIDARIEDADE                          90,020.08
# LIDMIN                                              82,832.52
# LIDERANÇA DO DEMOCRATAS                             67,103.60
# LIDERANÇA DO PTB                                    66,212.06
# LIDERANÇA DO PROGRESSISTAS                          64,875.00
# LIDERANÇA DO NOVO                                   46,608.76
# LIDERANÇA DO CIDADANIA                              45,555.09
# LIDERANÇA DO AVANTE                                 38,077.16
# ...

# %%
gastos_liderancas['Gasto total'].sum().round(2)
# Out:
# 1774102.72

# %%
df['vlrLiquido'].sum().round(2)
# Out:
# 449257677.06

# %% [markdown]
# Constatamos que ele representa somente 0,39% do valor total de gastos. Portanto resolvemos não considerar seus valores na soma dos gastos a serem realizadas por estado e por partido, por se tratar de um valor muito baixo.
# Consideramos ainda que não é possível identificar no dataset quem são essas lideranças e a quais estados elas pertencem.

# %% [markdown]
# ### <font size=15>**6.9. Há alguma correlação entre a quantidade de parlamentares por estado e o valor total dos gastos?**

# %%
total_parlamentar_valor = pd.concat([total_parlamentar_por_estado,total_estados],axis=1)
total_parlamentar_valor.rename(columns = {'txNomeParlamentar':'QTD_Parlamentar','vlrLiquido':'Gasto_Total'},inplace=True)
total_parlamentar_valor.index.name = 'UF'
total_parlamentar_valor
# Out:
#     QTD_Parlamentar   Gasto_Total
# UF
# SP              104 52,635,438.40
# RJ               82 36,707,801.80
# MG               81 43,162,671.56
# BA               56 39,441,897.60
# RS               47 25,075,845.74
# PR               46 26,785,753.60
# CE               39 21,933,892.08
# PE               38 21,591,701.23
# MA               34 18,126,874.79
# SC               30  9,722,726.40
# GO               27 14,416,890.65
# PA               27 16,469,118.51
# PB               20 12,161,287.75
# ES               17  7,982,895.03
# MS               16  6,942,314.37
# MT               15  7,184,822.30
# DF               15  4,303,815.07
# PI               15 10,105,986.48
# AP               15  8,930,724.82
# AC               14 10,293,532.20
# AL               14  7,640,373.82
# AM               14  8,698,992.79
# RO               13  5,926,355.59
# RR               13  7,854,212.79
# RN               13  7,500,253.34
# SE               12  7,970,503.96
# ...

# %%
plt.figure(figsize=(15,6))
sns.regplot(data=total_parlamentar_valor,x='QTD_Parlamentar',y='Gasto_Total',color='k')
plt.xlabel('Quantidade de parlamentares')
plt.ylabel('Total gasto em milhões de reais')
plt.title('Quantidade de parlamentares por estado X Gasto total por estado')
# Out:
# Text(0.5, 1.0, 'Quantidade de parlamentares por estado X Gasto total por estado')

# %%
total_parlamentar_valor_corr= total_parlamentar_valor.corr()
total_parlamentar_valor_corr
# Out:
#                  QTD_Parlamentar  Gasto_Total
# QTD_Parlamentar             1.00         0.97
# Gasto_Total                 0.97         1.00

# %%
sns.heatmap(total_parlamentar_valor_corr,vmin =-1.0,vmax=1.0,cmap='RdBu',annot=True)

# %% [markdown]
# Foi possível observar que há sim uma correlação positiva entre a quantidade de representantes e os valores gastos. Nesse gráfico regplot é possível ver que os pontos estão quase todos em cima da linha de tendência.
# É interessante ver que os 11 estados com menos representantes estão agrupados no início da linha. E que o estado que mais gasta está praticamente no final.
# Ou seja, é possível observar que os valores gastos estão diretamente ligados à quantidade de parlamentares que cada estado possui.

# %% [markdown]
# ###<font size=15> **6.10. Qual a média de gastos por partido?**

# %%
media_gastos_partido = df.groupby('sgPartido')[['vlrLiquido']].mean().sort_values('vlrLiquido',ascending=False)
media_gastos_partido
# Out:
#                vlrLiquido
# sgPartido
# PPL              2,246.29
# S.PART.          1,614.39
# PHS              1,295.36
# PRB              1,169.67
# REDE             1,151.66
# PCdoB            1,101.11
# PSC              1,092.36
# PR               1,090.14
# PROS             1,074.20
# PATRI            1,050.25
# SOLIDARIEDADE    1,028.81
# REPUBLICANOS     1,021.40
# PPS                970.75
# PL                 935.43
# DEM                918.02
# PDT                902.89
# PTB                878.04
# PSOL               850.62
# PSDB               847.95
# PSD                842.59
# PATRIOTA           840.10
# PODE               828.54
# MDB                818.61
# PP                 781.41
# PT                 747.82
# AVANTE             709.36
# PSB                682.99
# PV                 671.55
# CIDADANIA          583.45
# PSL                577.96
# NOVO               283.68

# %% [markdown]
# ### <font size=15>**6.11. Quais são os partidos que mais e que menos consumiram a cota parlamentar?**

# %% [markdown]
# Primeiro subimos o df com as cotas mensais disponiveis no site oficial da Câmara.

# %%
df_cotas = pd.read_csv('https://raw.githubusercontent.com/ViniciusCostaSouto/Projeto-Modulo-5-Grupo-9/main/cotas_mensais.csv', sep=';')
df_cotas.head()
# Out:
#   Estado Valor da Cota
# 0     AC     44.632,46
# 1     AL     40.944,10
# 2     AM     43.570,12
# 3     AP     43.374,78
# 4     BA     39.010,85

# %% [markdown]
# Depois nós agrupamos a quantidade de parlamentares por partido e estado.

# %%
qtde_parlamentares_uf = df.groupby(['sgPartido','sgUF'])[['txNomeParlamentar']].nunique()
qtde_parlamentares_uf.rename(columns={'txNomeParlamentar':'Qtde'},inplace = True)
qtde_parlamentares_uf
# Out:
#                     Qtde
# sgPartido     sgUF
# AVANTE        AL       1
#               AP       1
#               BA       2
#               CE       1
#               MG       4
# ...                  ...
# SOLIDARIEDADE RJ       1
#               RR       1
#               SE       1
#               SP       1
#               TO       2
#
# [425 rows x 1 columns]

# %% [markdown]
# Após isso, foi agrupado os valores liquido por partido e estado.

# %%
vlrLiquido_agrupado = df.groupby(['sgPartido','sgUF'])[['vlrLiquido']].sum().round(2)
vlrLiquido_agrupado
# Out:
#                      vlrLiquido
# sgPartido     sgUF
# AVANTE        AL      38,165.41
#               AP     755,907.46
#               BA   1,500,342.25
#               CE      24,793.92
#               MG   1,913,107.26
# ...                         ...
# SOLIDARIEDADE RJ     840,351.09
#               RR     828,788.42
#               SE   1,102,189.32
#               SP     616,188.84
#               TO   1,791,428.20
#
# [425 rows x 1 columns]

# %% [markdown]
# Depois disso juntamos os df gerados

# %%
resultado1 = qtde_parlamentares_uf.join(vlrLiquido_agrupado)
resultado1
# Out:
#                     Qtde   vlrLiquido
# sgPartido     sgUF
# AVANTE        AL       1    38,165.41
#               AP       1   755,907.46
#               BA       2 1,500,342.25
#               CE       1    24,793.92
#               MG       4 1,913,107.26
# ...                  ...          ...
# SOLIDARIEDADE RJ       1   840,351.09
#               RR       1   828,788.42
#               SE       1 1,102,189.32
#               SP       1   616,188.84
#               TO       2 1,791,428.20
#
# [425 rows x 2 columns]

# %% [markdown]
# Aqui juntamos os df's para começar a análise

# %%
resultado2 = resultado1.reset_index()
resultado2 = resultado2.set_index('sgUF')
df_cotas = df_cotas.set_index('Estado')
resultado2 = resultado2.join(df_cotas)
resultado3 = resultado2.reset_index()

# %% [markdown]
# Renomeamos a coluna index para UF depois de ter resetado o index

# %%
resultado3.rename(columns={'index':'UF'}, inplace=True)

# %% [markdown]
# Aqui é feito a conversão da coluna de valor da cota para float depois de alterar as virgulas e o ponto, além disso, essa coluna só pode ser rodada uma vez, por isso ela fica comentada.

# %%
resultado3['Valor da Cota'] = resultado3['Valor da Cota'].apply(lambda x: x.replace('.', ''))
resultado3['Valor da Cota'] = resultado3['Valor da Cota'].apply(lambda x: float(x.replace(',', '.')))
resultado3['Cota_Total'] = resultado3['Valor da Cota']*resultado3['Qtde']*31
resultado3['Cota_Restante'] = resultado3['Cota_Total'] - resultado3['vlrLiquido']
resultado3
# Out:
#      UF      sgPartido  Qtde   vlrLiquido  Valor da Cota   Cota_Total  \
# 0    AC            DEM     1 1,203,560.73      44,632.46 1,383,606.26
# 1    AC            MDB     2 2,747,208.74      44,632.46 2,767,212.52
# 2    AC          PCdoB     1 1,206,502.44      44,632.46 1,383,606.26
# 3    AC            PDT     1 1,287,145.48      44,632.46 1,383,606.26
# 4    AC            PSB     1    14,836.39      44,632.46 1,383,606.26
# ..   ..            ...   ...          ...            ...          ...
# 420  TO            PRB     1    44,325.67      39,503.61 1,224,611.91
# 421  TO           PROS     1    37,308.87      39,503.61 1,224,611.91
# 422  TO            PSC     1 1,062,720.78      39,503.61 1,224,611.91
# 423  TO             PT     1   814,110.24      39,503.61 1,224,611.91
# 424  TO  SOLIDARIEDADE     2 1,791,428.20      39,503.61 2,449,223.82
#
#      Cota_Restante
# 0       180,045.53
# 1        20,003.78
# 2       177,103.82
# 3        96,460.78
# 4     1,368,769.87
# ...

# %% [markdown]
# Aqui já conseguimos extrair os 5 maiores gastos do DF.

# %%
resultado4 = resultado3.groupby(['sgPartido','UF'])[['Cota_Total','vlrLiquido','Cota_Restante']].max()
Maior_Gasto = resultado4.sort_values('Cota_Restante', ascending = True)
Maior_Gasto.head()
# Out:
#                Cota_Total   vlrLiquido  Cota_Restante
# sgPartido UF
# PT        SE 1,244,317.06 1,272,097.86     -27,780.80
# PL        PB 1,303,009.36 1,328,756.77     -25,747.41
#           RN 1,324,691.69 1,331,131.21      -6,439.52
# DEM       MA 1,306,702.39 1,297,830.95       8,871.44
# PSD       PI 1,270,124.87 1,260,591.73       9,533.14

# %% [markdown]
# Com os dados extraidos, conseguimos plotar um gráfico de barras para mostrar os gastos.

# %%
maior = Maior_Gasto.head(5)
maior = maior.reset_index()
plt.figure(figsize = (12,6))
sns.barplot(data = maior, x='sgPartido',y='Cota_Restante' , hue='UF')
plt.xticks(rotation=90)
plt.xlabel('Partido')
plt.grid()
plt.legend().remove()

# %% [markdown]
# Depois disso, pegamos os valores dos 5 que menos gastaram

# %%
Menor_Gasto = resultado4.sort_values('Cota_Restante', ascending = False)
Menor_Gasto.head()
# Out:
#                 Cota_Total   vlrLiquido  Cota_Restante
# sgPartido UF
# PSDB      SP 17,225,241.45 6,701,398.41  10,523,843.04
# DEM       RJ 11,085,590.70 2,862,218.08   8,223,372.62
# PT        SP 14,928,542.59 7,325,073.91   7,603,468.68
# PR        SP  6,890,096.58   127,199.20   6,762,897.38
# PRB       SP  6,890,096.58   157,860.86   6,732,235.72

# %% [markdown]
# E aqui plotamos o gráfico com os dados obtidos acima

# %%
menor = Menor_Gasto.head(5)
menor = menor.reset_index()
plt.figure(figsize = (12,6))
sns.barplot(data = menor, x='sgPartido',y='Cota_Restante' , hue='UF')
plt.xticks(rotation=90)
plt.xlabel('Partido')
plt.grid()
plt.legend().remove()

# %% [markdown]
# ---

# %% [markdown]
# ###<font size=15> **6.12. Há alguma correlação entre a quantidade de parlamentares por partido e o valor total dos gastos?**

# %% [markdown]
# Começamos vendo a quantia de parlamentares por partido

# %%
total_parlamentar_por_partido = df[['sgPartido','txNomeParlamentar']].drop_duplicates().groupby('sgPartido').count().sort_values('txNomeParlamentar',ascending=False)
total_parlamentar_por_partido.head()
# Out:
#            txNomeParlamentar
# sgPartido
# PT                        79
# PP                        70
# PSDB                      66
# MDB                       64
# PSL                       59

# %% [markdown]
# Depois pegamos os gastos totais de cada partido

# %%
maiores_gastos_por_partido = df.groupby('sgPartido')[['vlrLiquido']].sum().sort_values('vlrLiquido',ascending=False)
maiores_gastos_por_partido.head(5)
# Out:
#              vlrLiquido
# sgPartido
# PT        53,101,273.58
# PSL       38,739,174.80
# PL        36,009,565.01
# PP        34,429,101.14
# MDB       31,505,872.66

# %% [markdown]
# Aqui juntamos os dois df

# %%
total_por_partido = pd.concat([total_parlamentar_por_partido,maiores_gastos_por_partido],axis=1)
total_por_partido.head()
# Out:
#            txNomeParlamentar    vlrLiquido
# sgPartido
# PT                        79 53,101,273.58
# PP                        70 34,429,101.14
# PSDB                      66 29,144,733.57
# MDB                       64 31,505,872.66
# PSL                       59 38,739,174.80

# %% [markdown]
# E por último calculamos a correlação entre as colunas

# %%
result = total_por_partido[['txNomeParlamentar','vlrLiquido']].corr().round(2)

# %% [markdown]
# Plotando um heatmap com os resultados, temos

# %%
sns.heatmap(result,vmin =-1.0,vmax=1.0,cmap='RdBu',annot=True)

# %%
plt.figure(figsize=(15,6))
sns.regplot(data=total_por_partido,x='txNomeParlamentar',y='vlrLiquido',color='k')
plt.xlabel('Quantidade de parlamentares')
plt.ylabel('Total gasto em milhões de reais')
plt.title('Quantidade de parlamentares por partido X Gasto total por partido')
# Out:
# Text(0.5, 1.0, 'Quantidade de parlamentares por partido X Gasto total por partido')

# %% [markdown]
# #<font size=15>**Questões sugeridas pela equipe:**

# %% [markdown]
# ###<font size=15> **6.13. Qual o valor máximo que um parlamentar ja gastou em um mês?**

# %%
teste= df.groupby(['numAno','numMes','txNomeParlamentar'])[['vlrLiquido']].sum()
teste.sort_values('vlrLiquido',ascending=False,inplace=True)

# %%
# Fiz a mesma coisa por ano, mas tem que ver se o grupo gosta dessa forma
data_2019.groupby('txNomeParlamentar')[['vlrLiquido']].mean().sort_values('vlrLiquido', ascending=False)
data_2020.groupby('txNomeParlamentar')[['vlrLiquido']].mean().sort_values('vlrLiquido', ascending=False)
data_2021.groupby('txNomeParlamentar')[['vlrLiquido']].mean().sort_values('vlrLiquido', ascending=False)
# Out:
#                        vlrLiquido
# txNomeParlamentar
# LIDERANÇA DO PDT        10,000.00
# Professor Alcides        6,031.19
# Paulo Freire Costa       5,624.93
# Silas Câmara             5,570.43
# José Nelto               5,226.99
# ...                           ...
# Arthur Lira               -289.72
# Paulo Eduardo Martins     -312.01
# Jorge Goetten             -418.23
# Felipe Carreras           -555.56
# Mauro Benevides Filho     -574.90
#
# [565 rows x 1 columns]

# %% [markdown]
# ### <font size=15>**6.14. Qual é a média mensal dos gastos por parlamentar**

# %%
# média de gastos por evento (gasto registrado)
questao2_1 = df.groupby('txNomeParlamentar')[['vlrLiquido']].mean().sort_values('vlrLiquido', ascending=False)
questao2_1.head()
# Out:
#                        vlrLiquido
# txNomeParlamentar
# JOSÉ REINALDO           13,452.61
# ALBERTO FRAGA           10,214.52
# DELEGADO FRANCISCHINI    8,975.94
# HEULER CRUVINEL          8,881.52
# CÉSAR HALUM              8,865.13

# %%
# Fazendo a media por mês e incluindo a contagem de ocorrencias
contagem = df.groupby(['txNomeParlamentar'])[['numMes']].count()
contagem.reset_index(inplace=True)
contagem.set_index('txNomeParlamentar',inplace=True)
contagem.columns = ['Count']
media_por_mes = df.groupby(['numAno','numMes','txNomeParlamentar'])[['vlrLiquido']].sum()\
    .groupby('txNomeParlamentar').mean().sort_values('vlrLiquido',ascending=False)
media_por_mes.columns=['Media']
media_cont_mes = pd.concat([media_por_mes,contagem],axis=1)
media_cont_mes.sort_values('Media',ascending=False).head()
# Out:
#                       Media  Count
# txNomeParlamentar
# ANTONIO IMBASSAHY 47,449.62     39
# ABEL MESQUITA JR. 45,888.19     15
# Jéssica Sales     45,660.00    515
# CÉSAR HALUM       44,325.67      5
# CARLOS ANDRADE    43,787.75     14

# %% [markdown]
# Para vizualizar melhor, fizemos um grafico de dispersão.
# Esse grafico nos dá uma noção de como os paralamentar gasta o dinheiro, por exemplo, há parlamentares que tem uma média gasto alta com muitas ocorrencias, outros com uma média de gasto baixa com muitas ocorrencias, outros com media de gastos alta com poucas ocorrencias.

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(data=media_cont_mes,y='Media',x='Count')
plt.xlabel('Ocorrencias')
plt.ylabel('Media mensal em reais')
plt.title('Media de gastos por mês x contagem de ocorrencias')
# Out:
# Text(0.5, 1.0, 'Media de gastos por mês x contagem de ocorrencias')

# %% [markdown]
# ###<font size=15> **6.15. Qual dia da semana que mais se usou recursos**

# %%
df.groupby('DiaSemana')[['vlrLiquido']].sum().sort_values('vlrLiquido',ascending=False)
# Out:
#               vlrLiquido
# DiaSemana
# Monday    102,149,256.97
# Tuesday    88,393,185.13
# Wednesday  85,103,126.28
# Thursday   77,183,640.25
# Friday     68,023,180.79
# Sunday     14,564,903.21
# Saturday   13,840,384.43

# %% [markdown]
# ---

# %% [markdown]
# ##<font size=15> **8. Conclusão**

# %% [markdown]
# ##<font size=15> **9. Referências**

# %% [markdown]
# **1)** [Operação Serenata de Amor](https://serenata.ai/): *Operação Serenata de Amor*, 2022. Disponível no [link](https://serenata.ai/).
#
# **2)** [Portal da Câmara dos Deputados](https://www2.camara.leg.br): *COTA PARA EXERCÍCIO DA ATIVIDADE PARLAMENTAR*, 2022. Disponível no [link](https://www2.camara.leg.br/transparencia/cota-para-exercicio-da-atividade-parlamentar/dados-abertos-cota-parlamentar).
#
# **3)** [Portal da Câmara dos Deputados](https://www2.camara.leg.br): *EXPLICAÇÕES SOBRE O FORMATO DOS ARQUIVOS XML*, 2022. Disponível no [link](https://www2.camara.leg.br/transparencia/cota-para-exercicio-da-atividade-parlamentar/explicacoes-sobre-o-formato-dos-arquivos-xml).
#
# **4)** [Github Docs](https://docs.github.com/pt/get-started/): *Sintaxe básica de escrita e formatação no GitHub*, 2022. Disponível no [link](https://docs.github.com/pt/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax).
#
# **5)** [Google Colab](https://colab.research.google.com/)`: *Markdown Guide*, 2022. Disponível no [link](https://colab.research.google.com/notebooks/markdown_guide.ipynb#scrollTo=5Y3CStVkLxqt).
#
# **6)** [Github](https://github.com): *Projeto Final do módulo IV - Grupo 6*, 2022. Disponível no [link](https://github.com/RhayzaPinto/Projeto_Modulo-IV/blob/main/Projeto%20M%C3%B3dulo%204%20-%20Dados%20-%20Branch%20Main.ipynb).
#
# **7)** [Github](https://github.com): *Projeto Final do módulo IV - Grupo 4*, 2022. Disponível no [link](https://github.com/brunnabrito/projeto_m4_g4_resilia).
#
# **8)** [Github](https://github.com): *Projeto Final do módulo IV - Grupo 1*, 2022. Disponível no [link](https://github.com/Brunoka02/Projeto_4/blob/main/Projeto_Modulo4.ipynb).
#
# **9)** [Kaggle](https://www.kaggle.com): *Projeto Final do módulo IV - Grupo 8*, 2022. Disponível no [link](https://www.kaggle.com/code/mrcioestevamdasilva/projeto-modulo-4-resilia/notebook).
#
# **10)** [Python](https://www.python.org/): *Documentação do Python*, 2022. Disponível no [link](https://docs.python.org/3/).
#
# **11)** [Pandas](https://pandas.pydata.org/): *Documentação do Pandas*, 2022. Disponível no [link](https://pandas.pydata.org/docs/).
#
# **12)** [Numpy](https://numpy.org/): *Documentação do Numpy*, 2022. Disponível no [link](https://numpy.org/doc/).
#
# **13)** [Matplotlib](https://matplotlib.org/): *Documentação do Numpy*, 2022. Disponível no [link](https://matplotlib.org/stable/index.html).
#
# **14)** [Seaborn](https://seaborn.pydata.org/): *Documentação do Numpy*, 2022. Disponível no [link](https://seaborn.pydata.org/examples/index.html).
#
# **15)** [Python Graph Galery](https://python-graph-gallery.com/): *Documentação do Python Graph Galery*, 2022. Disponível no [link](https://python-graph-gallery.com/).

# %% [markdown]
# ## <font size=15>**10. Apêndice**

# %% [markdown]
# Caso os valores fiquem em notação científica, é só rodar o código abaixo.

# %%
pd.options.display.float_format = '{:,.2f}'.format
#Caso as variáveis fiquem em notação científica, é só rodar essa janela
